# %% [markdown]
# Sample questions:
#
#     Q1: what type of busienss will have highest of inspection frequency per year
#     Q2: what is the most common infraction for restaurants
#     Q3: Which day of the week has the most inspections and the most fines.
#     Q4: Fines by establishment type
#     Q5: Which restaurant has most of fine
#     Q6: Which restaurant has the worst record, if we assign 3,2,1 as penalty mark for crucial, significant, minor

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# %matplotlib inline
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
np.random.seed(12345)
import matplotlib.pyplot as plt
plt.rc('figure', figsize=(10, 6))
PREVIOUS_MAX_ROWS = pd.options.display.max_rows
#pd.options.display.max_rows = 10
np.set_printoptions(precision=4, suppress=True)
import seaborn as sns

# %%
data = pd.read_csv('dinesafe.csv')

# %%
data.columns= map(str.lower, data.columns)

# %%
data['inspection_date'] = pd.to_datetime(data['inspection_date'])
data['year'] = pd.DatetimeIndex(data['inspection_date']).year
data['quarter'] = pd.DatetimeIndex(data['inspection_date']).quarter
data['month'] = pd.DatetimeIndex(data['inspection_date']).month
data['week'] = pd.DatetimeIndex(data['inspection_date']).week

# %%
data.head(5)
# Out:
#    row_id  establishment_id  inspection_id  \
# 0   89798          10638787      104258049
# 1   81982          10599890      103998046
# 2   81983          10599890      104223135
# 3   13393           9031951      103823167
# 4   13394           9031951      103956830
#
#                              establishment_name  \
# 0                                        FRESCO
# 1                                  MAYWAH FOODS
# 2                                  MAYWAH FOODS
# 3  CLAIREPORT PLACE BANQUET & CONVENTION CENTRE
# 4  CLAIREPORT PLACE BANQUET & CONVENTION CENTRE
#
#                     establishmenttype establishment_address   latitude  \
# 0                         Supermarket     559 SHERBOURNE ST  43.669275
# 1  Food Store (Convenience / Variety)    20 CLAIREPORT CRES  43.746679
# 2  Food Store (Convenience / Variety)    20 CLAIREPORT CRES  43.746679
# 3                    Banquet Facility    65 CLAIREPORT CRES  43.746105
# 4                    Banquet Facility    65 CLAIREPORT CRES  43.746105
#
#    longitude establishment_status  minimum_inspections_peryear  \
# 0 -79.375251                 Pass                            2
# 1 -79.632725                 Pass                            1
# 2 -79.632725                 Pass                            1
# 3 -79.631265                 Pass                            3
# 4 -79.631265                 Pass                            3
#
#   infraction_details inspection_date severity action court_outcome  \
# 0                NaN      2018-07-06      NaN    NaN           NaN
# 1                NaN      2017-05-25      NaN    NaN           NaN
# 2                NaN      2018-05-18      NaN    NaN           NaN
# 3                NaN      2016-10-02      NaN    NaN           NaN
# 4                NaN      2017-04-27      NaN    NaN           NaN
#
#    amount_fined  year  quarter  month  week
# 0           NaN  2018        3      7    27
# 1           NaN  2017        2      5    21
# 2           NaN  2018        2      5    20
# 3           NaN  2016        4     10    39
# 4           NaN  2017        2      4    17

# %%
data.shape
# Out:
# (90520, 20)

# %%
data.describe()
# Out:
#              row_id  establishment_id  inspection_id      latitude  \
# count  90520.000000      9.052000e+04   9.052000e+04  90520.000000
# mean   45260.500000      1.018466e+07   1.040637e+08     43.699607
# std    26131.017521      5.903924e+05   1.419047e+05      0.054377
# min        1.000000      1.222579e+06   1.033519e+08     43.586770
# 25%    22630.750000      1.025015e+07   1.039429e+08     43.654925
# 50%    45260.500000      1.045186e+07   1.040687e+08     43.680659
# 75%    67890.250000      1.055421e+07   1.041859e+08     43.743924
# max    90520.000000      1.064847e+07   1.043102e+08     43.839139
#
#           longitude  minimum_inspections_peryear  amount_fined          year  \
# count  90520.000000                 90520.000000    263.000000  90520.000000
# mean     -79.395151                     2.342830    218.659696   2017.252165
# std        0.081528                     0.627003    271.487472      0.669984
# min      -79.632725                     1.000000      0.000000   2016.000000
# 25%      -79.438232                     2.000000     60.000000   2017.000000
# 50%      -79.393629                     2.000000    120.000000   2017.000000
# 75%      -79.350568                     3.000000    305.000000   2018.000000
# max      -79.130693                     3.000000   1875.000000   2018.000000
#
#             quarter         month          week
# count  90520.000000  90520.000000  90520.000000
# mean       2.502784      6.515234     26.609722
# std        1.116435      3.414647     14.803786
# min        1.000000      1.000000      1.000000
# 25%        2.000000      4.000000     14.000000
# 50%        2.000000      6.000000     26.000000
# 75%        4.000000     10.000000     40.000000
# max        4.000000     12.000000     52.000000

# %%
data.isnull().sum().sort_values(ascending=False).head(8)
# Out:
# amount_fined          90257
# court_outcome         89739
# action                28822
# severity              28822
# infraction_details    28822
# week                      0
# latitude                  0
# establishment_id          0
# dtype: int64

# %%
#data['amount_fined'] = data['amount_fined'].fillna(0) #complete missing fine with zero?

# %%
#data.isnull().sum().sort_values(ascending=False)

# %%
#noAction = data[data["action"].isnull()]
#noAction

# %%
#noAction['establishment_status'].value_counts()

# %%
data['establishment_status'].value_counts()
# Out:
# Pass                72931
# Conditional Pass    17237
# Closed                352
# Name: establishment_status, dtype: int64

# %%
data['establishmenttype'].value_counts()
# Out:
# Restaurant                                  49016
# Food Take Out                               13119
# Food Store (Convenience / Variety)           4448
# Supermarket                                  3209
# Food Court Vendor                            3196
# Bakery                                       2454
# Child Care - Catered                         2027
# Child Care - Food Preparation                1738
# Food Caterer                                  938
# Banquet Facility                              901
# Butcher Shop                                  895
# Food Processing Plant                         885
# Cafeteria                                     818
# Retirement Homes(Licensed)                    697
# Nursing Home / Home for the Aged              505
# Cafeteria - Public Access                     495
# Community Kitchen Meal Program                461
# School Nourishment Program                    439
# Cocktail Bar / Beverage Room                  433
# Institutional Food Service                    416
# Boarding / Lodging Home - Kitchen             372
# Private Club                                  354
# Food Depot                                    316
# Secondary School Food Services                269
# Bake Shop                                     243
# Serving Kitchen                               243
# Commissary                                    208
# Ice Cream / Yogurt Vendors                    163
# Hospitals & Health Facilities                 162
# Fish Shop                                     152
# Hot Dog Cart                                  111
# Refreshment Stand (Stationary)                109
# Food Bank                                      97
# College/University Food services               92
# Flea Market                                    87
# Elementary School Food services                75
# Mobile Food Preparation Premises               70
# Church Banquet Facility                        36
# Food Vending Facility                          32
# Meat Processing Plant                          32
# Chartered Cruise Boats                         27
# Other Educational Facility Food Services       26
# Fairs / Festivals / Special Occasions          25
# Rest Home                                      23
# Retirement Homes(Un-licensed)                  22
# Catering Vehicle                               22
# Brew Your Own Beer / Wine                      19
# Food Cart                                      13
# Bottling Plant                                 13
# Milk Pasteurization Plant                       6
# Bed & Breakfast                                 3
# Cheese Plant                                    3
# Ice Cream Plant                                 2
# Locker Plant                                    2
# Food Recovery Program                           1
# Name: establishmenttype, dtype: int64

# %%
fine_table =data.pivot_table(values=["amount_fined"], index=["establishment_status","establishmenttype"], aggfunc=np.sum)

# %%
fine_table
# Out:
#                                                                amount_fined
# establishment_status establishmenttype
# Closed               Bake Shop                                          0.0
#                      Bakery                                             0.0
#                      Catering Vehicle                                   0.0
#                      Food Court Vendor                                  0.0
#                      Food Processing Plant                              0.0
#                      Food Store (Convenience / Variety)                 0.0
#                      Food Take Out                                      0.0
#                      Mobile Food Preparation Premises                   0.0
#                      Restaurant                                       360.0
# Conditional Pass     Bake Shop                                          0.0
#                      Bakery                                          1120.0
#                      Banquet Facility                                   0.0
#                      Boarding / Lodging Home - Kitchen                  0.0
#                      Bottling Plant                                     0.0
#                      Brew Your Own Beer / Wine                          0.0
#                      Butcher Shop                                     235.0
#                      Cafeteria                                          0.0
#                      Cafeteria - Public Access                          0.0
#                      Chartered Cruise Boats                             0.0
#                      Child Care - Catered                               0.0
#                      Child Care - Food Preparation                      0.0
#                      Church Banquet Facility                            0.0
#                      Cocktail Bar / Beverage Room                       0.0
#                      College/University Food services                   0.0
#                      Commissary                                         0.0
#                      Community Kitchen Meal Program                     0.0
#                      Elementary School Food services                    0.0
#                      Fish Shop                                          0.0
#                      Flea Market                                        0.0
#                      Food Bank                                          0.0
# ...                                                                     ...
# Pass                 Food Cart                                          0.0
#                      Food Caterer                                       0.0
#                      Food Court Vendor                                  0.0
#                      Food Depot                                         0.0
#                      Food Processing Plant                            240.0
#                      Food Recovery Program                              0.0
#                      Food Store (Convenience / Variety)               875.0
#                      Food Take Out                                   2115.0
#                      Food Vending Facility                              0.0
#                      Hospitals & Health Facilities                      0.0
#                      Hot Dog Cart                                       0.0
#                      Ice Cream / Yogurt Vendors                         0.0
#                      Ice Cream Plant                                    0.0
#                      Institutional Food Service                         0.0
#                      Locker Plant                                       0.0
#                      Meat Processing Plant                              0.0
#                      Milk Pasteurization Plant                          0.0
#                      Mobile Food Preparation Premises                   0.0
#                      Nursing Home / Home for the Aged                   0.0
#                      Other Educational Facility Food Services           0.0
#                      Private Club                                       0.0
#                      Refreshment Stand (Stationary)                     0.0
#                      Rest Home                                          0.0
#                      Restaurant                                      4114.0
#                      Retirement Homes(Licensed)                         0.0
#                      Retirement Homes(Un-licensed)                      0.0
#                      School Nourishment Program                         0.0
#                      Secondary School Food Services                     0.0
#                      Serving Kitchen                                    0.0
#                      Supermarket                                     1000.0
#
# [108 rows x 1 columns]

# %% [markdown]
# ### Q4: Fines by establishment type

# %%
fine_table.sort_values(by=['establishment_status','amount_fined'],ascending=[False,False])
# Out:
#                                                             amount_fined
# establishment_status establishmenttype
# Pass                 Restaurant                                   4114.0
#                      Food Take Out                                2115.0
#                      Supermarket                                  1000.0
#                      Food Store (Convenience / Variety)            875.0
#                      Food Processing Plant                         240.0
#                      Bakery                                        105.0
#                      Cafeteria                                      60.0
#                      Bake Shop                                       0.0
#                      Banquet Facility                                0.0
#                      Bed & Breakfast                                 0.0
#                      Boarding / Lodging Home - Kitchen               0.0
#                      Bottling Plant                                  0.0
#                      Brew Your Own Beer / Wine                       0.0
#                      Butcher Shop                                    0.0
#                      Cafeteria - Public Access                       0.0
#                      Catering Vehicle                                0.0
#                      Chartered Cruise Boats                          0.0
#                      Cheese Plant                                    0.0
#                      Child Care - Catered                            0.0
#                      Child Care - Food Preparation                   0.0
#                      Church Banquet Facility                         0.0
#                      Cocktail Bar / Beverage Room                    0.0
#                      College/University Food services                0.0
#                      Commissary                                      0.0
#                      Community Kitchen Meal Program                  0.0
#                      Elementary School Food services                 0.0
#                      Fairs / Festivals / Special Occasions           0.0
#                      Fish Shop                                       0.0
#                      Flea Market                                     0.0
#                      Food Bank                                       0.0
# ...                                                                  ...
# Conditional Pass     Elementary School Food services                 0.0
#                      Fish Shop                                       0.0
#                      Flea Market                                     0.0
#                      Food Bank                                       0.0
#                      Food Caterer                                    0.0
#                      Food Processing Plant                           0.0
#                      Food Vending Facility                           0.0
#                      Hot Dog Cart                                    0.0
#                      Ice Cream / Yogurt Vendors                      0.0
#                      Institutional Food Service                      0.0
#                      Meat Processing Plant                           0.0
#                      Mobile Food Preparation Premises                0.0
#                      Nursing Home / Home for the Aged                0.0
#                      Private Club                                    0.0
#                      Refreshment Stand (Stationary)                  0.0
#                      Rest Home                                       0.0
#                      Retirement Homes(Licensed)                      0.0
#                      Retirement Homes(Un-licensed)                   0.0
#                      School Nourishment Program                      0.0
#                      Secondary School Food Services                  0.0
#                      Serving Kitchen                                 0.0
# Closed               Restaurant                                    360.0
#                      Bake Shop                                       0.0
#                      Bakery                                          0.0
#                      Catering Vehicle                                0.0
#                      Food Court Vendor                               0.0
#                      Food Processing Plant                           0.0
#                      Food Store (Convenience / Variety)              0.0
#                      Food Take Out                                   0.0
#                      Mobile Food Preparation Premises                0.0
#
# [108 rows x 1 columns]

# %%
severity_table =data.pivot_table(values=['amount_fined'], index=['minimum_inspections_peryear'], aggfunc=np.sum)

# %%
severity_inspections= severity_table.sort_values('minimum_inspections_peryear',ascending=[False])

# %%
severity_inspections.plot.bar()

# %% [markdown]
# ### Top 50 fined places

# %%
top50fined = data.sort_values(['amount_fined'], ascending=False).head(50)
locations= top50fined[['latitude','longitude']]
mapLoc = locations.drop_duplicates().values.tolist()
import gmaps
import gmaps.datasets
gmaps.configure(api_key="AIzaSyCVTancsro9MENTLl90aaNu4-tLPdSnmH8") # Your Google API key

# load a Numpy array of (latitude, longitude) pairs
fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(mapLoc))
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
result = data.groupby(['establishment_name'])['amount_fined'].aggregate(np.sum).reset_index().sort_values('amount_fined', ascending=False)
result.iloc[:10,:]
# Out:
#                    establishment_name  amount_fined
# 7779                       OLD SCHOOL        3625.0
# 12217           WAI YU LAU RESTAURANT        3000.0
# 12105                     VESTA LUNCH        2910.0
# 1201               BITONDO'S PIZZERIA        2250.0
# 3863      FRESH & DELICIOUS FAST FOOD        2000.0
# 9504                       SECOND CUP        1654.0
# 9495                         SEASPRAY        1495.0
# 8827         RAIDERS E- SPORTS CENTRE        1440.0
# 1090   BERNARD'S PILIPINO SPECIALTIES        1320.5
# 3759           FOOD DEPOT SUPERMARKET        1300.0

# %%
data[data.establishment_name == 'WAI YU LAU RESTAURANT']['severity'].value_counts()
# Out:
# M - Minor          12
# S - Significant     7
# C - Crucial         3
# Name: severity, dtype: int64

# %%
#data[data.establishment_name == 'OLD SCHOOL']

# %%
#pd.to_datetime(data['inspection_date'])

# %%
#data.sort_values(['inspection_date'])

# %%
#data

# %% [markdown]
# ### Q1: what busienss will have highest of inspection frequency per year

# %%
count_establishment = data.groupby(['establishment_address', 'establishment_name']).size()

# %%
new_df = count_establishment.to_frame(name = 'size').reset_index()

# %%
new_df.sort_values(['size'],ascending = False).head(20)
# Out:
#          establishment_address                   establishment_name  size
# 9456          3401 DUFFERIN ST  VILLA MADINA  MEDITERRANEAN CUISINE    86
# 15422           866 WILSON AVE                              MUSTAFA    59
# 6753          2450 DUFFERIN ST                   YUM YUM RESTAURANT    56
# 12401  531 WILSON HEIGHTS BLVD                   TIMES SQUARE DINER    53
# 583            1008 WILSON AVE                          PHO MI ASIA    53
# 9748         3555 DON MILLS RD         TASTY BBQ SEAFOOD RESTAURANT    52
# 7945            288 WILSON AVE                            JOLLYTOPS    52
# 11179      4466 SHEPPARD AVE E               FARM FRESH SUPERMARKET    51
# 8873          3220 DUFFERIN ST                          SEOUL HOUSE    51
# 12062            5000 YONGE ST                          BATON ROUGE    48
# 710         1027 STEELES AVE W     KIVA'S BAGEL BAKERY & RESTAURANT    48
# 6475             2350 YONGE ST                            STAR KING    47
# 11682      4810 SHEPPARD AVE E             BABU CATERING & TAKE OUT    47
# 9333            336 WILSON AVE                          BAGEL WORLD    45
# 7944            288 WILSON AVE                        CUSINA LOUNGE    45
# 4719           1955 QUEEN ST E            POPEYES LOUISIANA KITCHEN    44
# 8831          3203 DUFFERIN ST              LUCKY DRAGON RESTAURANT    43
# 8825          3200 DUFFERIN ST         KRYSTOS MODERN GREEK CUISINE    41
# 1037           1090 WILSON AVE                                METRO    41
# 7206    2555 VICTORIA PARK AVE                 HONG TAI SUPERMARKET    41

# %%
data[data.establishment_address == '3401 DUFFERIN ST']['establishment_status'].value_counts()
# Out:
# Conditional Pass    299
# Pass                280
# Name: establishment_status, dtype: int64

# %%
mapLoc = locations.drop_duplicates().values.tolist()

# %%
import gmaps
import gmaps.datasets
gmaps.configure(api_key="AIzaSyCVTancsro9MENTLl90aaNu4-tLPdSnmH8") # Your Google API key

# load a Numpy array of (latitude, longitude) pairs
fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(mapLoc))
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Q2: what is the most common infraction for restaurants

# %%
count_infraction_details = data.groupby(['infraction_details']).size()

# %%
new_infraction_details = count_infraction_details.to_frame(name = 'size').reset_index()

# %%
cleaned_10 = new_infraction_details.sort_values(['size'],ascending = False)
cleaned_10 = cleaned_10[:10]
cleaned_10
# Out:
#                                     infraction_details  size
# 363   Operator fail to properly wash surfaces in rooms  8822
# 354           Operator fail to properly maintain rooms  7145
# 360           Operator fail to properly wash equipment  5961
# 351  Operator fail to properly maintain equipment(N...  2350
# 376          Operator fail to provide proper equipment  1909
# 64   Fail to Ensure the Presence of the Holder of a...  1540
# 39   FAIL TO PROVIDE THERMOMETER IN STORAGE COMPART...  1297
# 25   FAIL TO HAVE TEST REAGENT AVAILABLE AT  PLACE ...  1252
# 392  Operator fail to use proper procedure(s) to en...  1196
# 157                 Food handler fail to wear headgear  1133

# %%
cleaned_10.plot.bar(x='infraction_details', y='size',figsize=(12,6))

# %%
#num_inspection = data.groupby('inspection_date')[.count()
num_inspection = data.groupby(['year','week'])['inspection_id'].nunique().reset_index()
#num_inspection= num_inspection.set_index(['year','week'])
num_inspection= num_inspection.rename(columns={'inspection_id':'num_of_inspections'})
#num_inspection.index = pd.to_datetime(num_inspection.index)
num_inspection
# Out:
#      year  week  num_of_inspections
# 0    2016    38                  25
# 1    2016    39                 576
# 2    2016    40                 593
# 3    2016    41                 562
# 4    2016    42                 687
# 5    2016    43                 600
# 6    2016    44                 527
# 7    2016    45                 450
# 8    2016    46                 578
# 9    2016    47                 543
# 10   2016    48                 527
# 11   2016    49                 717
# 12   2016    50                 577
# 13   2016    51                 604
# 14   2016    52                 227
# 15   2017     1                 222
# 16   2017     2                 448
# 17   2017     3                 479
# 18   2017     4                 459
# 19   2017     5                 579
# 20   2017     6                 581
# 21   2017     7                 551
# 22   2017     8                 437
# 23   2017     9                 507
# 24   2017    10                 560
# 25   2017    11                 440
# 26   2017    12                 551
# 27   2017    13                 614
# 28   2017    14                 585
# 29   2017    15                 421
# ..    ...   ...                 ...
# 75   2018     9                 577
# 76   2018    10                 601
# 77   2018    11                 600
# 78   2018    12                 553
# 79   2018    13                 384
# 80   2018    14                 362
# 81   2018    15                 576
# 82   2018    16                 616
# 83   2018    17                 624
# 84   2018    18                 575
# 85   2018    19                 513
# 86   2018    20                 602
# 87   2018    21                 511
# 88   2018    22                 517
# 89   2018    23                 551
# 90   2018    24                 495
# 91   2018    25                 484
# 92   2018    26                 594
# 93   2018    27                 354
# 94   2018    28                 491
# 95   2018    29                 632
# 96   2018    30                 651
# 97   2018    31                 664
# 98   2018    32                 507
# 99   2018    33                 578
# 100  2018    34                 592
# 101  2018    35                 585
# 102  2018    36                 335
# 103  2018    37                 554
# 104  2018    38                 550
#
# [105 rows x 3 columns]

# %%
num_inspection['new'] = num_inspection.year.astype(str) + '-' + num_inspection.week.astype(str)

# %%
num_inspection
# Out:
#      year  week  num_of_inspections      new
# 0    2016    38                  25  2016-38
# 1    2016    39                 576  2016-39
# 2    2016    40                 593  2016-40
# 3    2016    41                 562  2016-41
# 4    2016    42                 687  2016-42
# 5    2016    43                 600  2016-43
# 6    2016    44                 527  2016-44
# 7    2016    45                 450  2016-45
# 8    2016    46                 578  2016-46
# 9    2016    47                 543  2016-47
# 10   2016    48                 527  2016-48
# 11   2016    49                 717  2016-49
# 12   2016    50                 577  2016-50
# 13   2016    51                 604  2016-51
# 14   2016    52                 227  2016-52
# 15   2017     1                 222   2017-1
# 16   2017     2                 448   2017-2
# 17   2017     3                 479   2017-3
# 18   2017     4                 459   2017-4
# 19   2017     5                 579   2017-5
# 20   2017     6                 581   2017-6
# 21   2017     7                 551   2017-7
# 22   2017     8                 437   2017-8
# 23   2017     9                 507   2017-9
# 24   2017    10                 560  2017-10
# 25   2017    11                 440  2017-11
# 26   2017    12                 551  2017-12
# 27   2017    13                 614  2017-13
# 28   2017    14                 585  2017-14
# 29   2017    15                 421  2017-15
# ..    ...   ...                 ...      ...
# 75   2018     9                 577   2018-9
# 76   2018    10                 601  2018-10
# 77   2018    11                 600  2018-11
# 78   2018    12                 553  2018-12
# 79   2018    13                 384  2018-13
# 80   2018    14                 362  2018-14
# 81   2018    15                 576  2018-15
# 82   2018    16                 616  2018-16
# 83   2018    17                 624  2018-17
# 84   2018    18                 575  2018-18
# 85   2018    19                 513  2018-19
# 86   2018    20                 602  2018-20
# 87   2018    21                 511  2018-21
# 88   2018    22                 517  2018-22
# 89   2018    23                 551  2018-23
# 90   2018    24                 495  2018-24
# 91   2018    25                 484  2018-25
# 92   2018    26                 594  2018-26
# 93   2018    27                 354  2018-27
# 94   2018    28                 491  2018-28
# 95   2018    29                 632  2018-29
# 96   2018    30                 651  2018-30
# 97   2018    31                 664  2018-31
# 98   2018    32                 507  2018-32
# 99   2018    33                 578  2018-33
# 100  2018    34                 592  2018-34
# 101  2018    35                 585  2018-35
# 102  2018    36                 335  2018-36
# 103  2018    37                 554  2018-37
# 104  2018    38                 550  2018-38
#
# [105 rows x 4 columns]

# %%
ax = num_inspection.plot(x='new',y='num_of_inspections',figsize=(20,8))
ax.set_xticklabels(num_inspection["new"]);

# %%
num_inspection.dtypes
# Out:
# num_of_inspections    int64
# dtype: object

# %%
data_17 = data[data['year'] ==2017]
data_17
# Out:
#        row_id  establishment_id  inspection_id  \
# 1       81982          10599890      103998046
# 4       13394           9031951      103956830
# 5       13395           9031951      104036198
# 6       13396           9031951      104103384
# 10      21301          10223823      103975718
# 11      21302          10223823      104076230
# 14      16612           9391807      103977859
# 17      65552          10546285      103911424
# 18      65553          10546285      104019626
# 19      65554          10546285      104019626
# 20      65555          10546285      104076203
# 21      65556          10546285      104076203
# 25      30131          10348496      103911428
# 26      32176          10362037      103911430
# 27      32177          10362037      104048251
# 31      73977          10574909      103975740
# 32      73978          10574909      104079368
# 33      69584          10559975      103911426
# 34      69585          10559975      103911426
# 35      69586          10559975      104019631
# 38       4864           9007848      103965983
# 39       4865           9007848      104079370
# 43       8296           9012981      103957119
# 44       8297           9012981      104036197
# 45       8298           9012981      104103383
# 49      69011          10557677      103965986
# 52      25662          10291253      103980775
# 53      25663          10291253      103980775
# 54      25664          10291253      103980775
# 55      25665          10291253      103986749
# ...       ...               ...            ...
# 90457   21597          10228616      103969413
# 90462   86171          10617438      104108739
# 90464   16117           9364488      103960141
# 90465   16118           9364488      103960141
# 90466   16119           9364488      103960151
# 90467   16120           9364488      104050386
# 90473   37124          10397899      103929843
# 90474   37125          10397899      104050380
# 90481   57601          10514071      103898933
# 90484   28330          10326909      103929839
# 90485   28912          10332939      103963764
# 90486   83376          10606138      104034455
# 90487   83377          10606138      104034455
# 90488   83378          10606138      104034457
# 90489   83379          10606138      104074581
# 90492   43468          10439706      103888332
# 90493   43469          10439706      103888332
# 90494   43470          10439706      103888343
# 90495   43471          10439706      104052120
# 90496    7648           9012206      103947831
# 90498   57603          10514119      103970875
# 90501    1793           9002748      103898918
# 90502    1794           9002748      104050877
# 90505   25254          10287417      103970877
# 90508   43571          10440820      103970917
# 90510   49782          10478328      103888363
# 90511   49783          10478328      104052138
# 90515   56795          10510660      103903509
# 90516   56796          10510660      103969313
# 90517   56797          10510660      104074578
#
#                                  establishment_name  \
# 1                                      MAYWAH FOODS
# 4      CLAIREPORT PLACE BANQUET & CONVENTION CENTRE
# 5      CLAIREPORT PLACE BANQUET & CONVENTION CENTRE
# 6      CLAIREPORT PLACE BANQUET & CONVENTION CENTRE
# 10                                  DECO AUTOMOTIVE
# 11                                  DECO AUTOMOTIVE
# 14                       APOTEX ETOBICOKE CAFETERIA
# 17                                  TANDOORI KUZANA
# 18                                  TANDOORI KUZANA
# 19                                  TANDOORI KUZANA
# 20                                  TANDOORI KUZANA
# 21                                  TANDOORI KUZANA
# 25                                             ESSO
# 26                                    COUNTRY STYLE
# 27                                    COUNTRY STYLE
# 31                                     BAPS SHAYONA
# 32                                     BAPS SHAYONA
# 33                                       FIORUCCI'S
# 34                                       FIORUCCI'S
# 35                                       FIORUCCI'S
# 38                          JOE'S FOOD DISTRIBUTORS
# 39                          JOE'S FOOD DISTRIBUTORS
# 43                               RIZZO BANQUET HALL
# 44                               RIZZO BANQUET HALL
# 45                               RIZZO BANQUET HALL
# 49                             ECLECTIC LOUNGE INC.
# 52      UNITED STAR SEAFOOD & SHEIK HALAL FARMS INC
# 53      UNITED STAR SEAFOOD & SHEIK HALAL FARMS INC
# 54      UNITED STAR SEAFOOD & SHEIK HALAL FARMS INC
# 55      UNITED STAR SEAFOOD & SHEIK HALAL FARMS INC
# ...                                             ...
# 90457                       MIKE & LORI'S NO FRILLS
# 90462                                   Smokey Jo's
# 90464                             PORT UNION BAKERY
# 90465                             PORT UNION BAKERY
# 90466                             PORT UNION BAKERY
# 90467                             PORT UNION BAKERY
# 90473                                   THAI SQUARE
# 90474                                   THAI SQUARE
# 90481                            PASTA TUTTI GIORNI
# 90484                                         METRO
# 90485                                 BLACK DOG PUB
# 90486                        Yummy Wok Chinese Food
# 90487                        Yummy Wok Chinese Food
# 90488                        Yummy Wok Chinese Food
# 90489                        Yummy Wok Chinese Food
# 90492                    AZUMI TEPPANYAKI AND SUSHI
# 90493                    AZUMI TEPPANYAKI AND SUSHI
# 90494                    AZUMI TEPPANYAKI AND SUSHI
# 90495                    AZUMI TEPPANYAKI AND SUSHI
# 90496                                   PIZZA PIZZA
# 90498                                           KFC
# 90501                      CHARLOTTETOWN BLVD CHILD
# 90502                      CHARLOTTETOWN BLVD CHILD
# 90505                                        SUBWAY
# 90508                      SIMPLY FROSTED CUPCAKERY
# 90510                             MR BEAN COFFEE CO
# 90511                             MR BEAN COFFEE CO
# 90515      Birdsilver Gardens Senior Support Centre
# 90516      Birdsilver Gardens Senior Support Centre
# 90517      Birdsilver Gardens Senior Support Centre
#
#                         establishmenttype establishment_address   latitude  \
# 1      Food Store (Convenience / Variety)    20 CLAIREPORT CRES  43.746679
# 4                        Banquet Facility    65 CLAIREPORT CRES  43.746105
# 5                        Banquet Facility    65 CLAIREPORT CRES  43.746105
# 6                        Banquet Facility    65 CLAIREPORT CRES  43.746105
# 10                              Cafeteria    225 CLAIREVILLE DR  43.746534
# 11                              Cafeteria    225 CLAIREVILLE DR  43.746534
# 14                              Cafeteria      50 STEINWAY BLVD  43.750450
# 17                             Restaurant    21 SIGNAL HILL AVE  43.752253
# 18                             Restaurant    21 SIGNAL HILL AVE  43.752253
# 19                             Restaurant    21 SIGNAL HILL AVE  43.752253
# 20                             Restaurant    21 SIGNAL HILL AVE  43.752253
# 21                             Restaurant    21 SIGNAL HILL AVE  43.752253
# 25     Food Store (Convenience / Variety)    6953 STEELES AVE W  43.752755
# 26                             Restaurant    6953 STEELES AVE W  43.752755
# 27                             Restaurant    6953 STEELES AVE W  43.752755
# 31                          Food Take Out     46 CLAIREVILLE DR  43.737996
# 32                          Food Take Out     46 CLAIREVILLE DR  43.737996
# 33                             Restaurant    6923 STEELES AVE W  43.752950
# 34                             Restaurant    6923 STEELES AVE W  43.752950
# 35                             Restaurant    6923 STEELES AVE W  43.752950
# 38     Food Store (Convenience / Variety)      24 STEINWAY BLVD  43.751939
# 39     Food Store (Convenience / Variety)      24 STEINWAY BLVD  43.751939
# 43                       Banquet Facility        1941 ALBION RD  43.746553
# 44                       Banquet Facility        1941 ALBION RD  43.746553
# 45                       Banquet Facility        1941 ALBION RD  43.746553
# 49                             Restaurant       2 STEINWAY BLVD  43.753427
# 52                           Butcher Shop      12 STEINWAY BLVD  43.752887
# 53                           Butcher Shop      12 STEINWAY BLVD  43.752887
# 54                           Butcher Shop      12 STEINWAY BLVD  43.752887
# 55                           Butcher Shop      12 STEINWAY BLVD  43.752887
# ...                                   ...                   ...        ...
# 90457                         Supermarket          70 ISLAND RD  43.798229
# 90462                          Restaurant     297 PORT UNION RD  43.789572
# 90464                              Bakery     287 PORT UNION RD  43.789364
# 90465                              Bakery     287 PORT UNION RD  43.789364
# 90466                              Bakery     287 PORT UNION RD  43.789364
# 90467                              Bakery     287 PORT UNION RD  43.789364
# 90473                          Restaurant     277 PORT UNION RD  43.789052
# 90474                          Restaurant     277 PORT UNION RD  43.789052
# 90481                          Restaurant          98 ISLAND RD  43.798392
# 90484                         Supermarket     261 PORT UNION RD  43.788508
# 90485                          Restaurant          87 ISLAND RD  43.797681
# 90486                          Restaurant          515 EAST AVE  43.798683
# 90487                          Restaurant          515 EAST AVE  43.798683
# 90488                          Restaurant          515 EAST AVE  43.798683
# 90489                          Restaurant          515 EAST AVE  43.798683
# 90492                          Restaurant   5514 LAWRENCE AVE E  43.779194
# 90493                          Restaurant   5514 LAWRENCE AVE E  43.779194
# 90494                          Restaurant   5514 LAWRENCE AVE E  43.779194
# 90495                          Restaurant   5514 LAWRENCE AVE E  43.779194
# 90496                          Restaurant   5500 LAWRENCE AVE E  43.779454
# 90498                       Food Take Out   5500 LAWRENCE AVE E  43.779454
# 90501                Child Care - Catered         111 ISLAND RD  43.797804
# 90502                Child Care - Catered         111 ISLAND RD  43.797804
# 90505                          Restaurant   5550 LAWRENCE AVE E  43.779696
# 90508                              Bakery   5550 LAWRENCE AVE E  43.779696
# 90510                          Restaurant   5550 LAWRENCE AVE E  43.779696
# 90511                          Restaurant   5550 LAWRENCE AVE E  43.779696
# 90515    Nursing Home / Home for the Aged    16 BIRDSILVER GDNS  43.791990
# 90516    Nursing Home / Home for the Aged    16 BIRDSILVER GDNS  43.791990
# 90517    Nursing Home / Home for the Aged    16 BIRDSILVER GDNS  43.791990
#
#        longitude establishment_status  minimum_inspections_peryear  \
# 1     -79.632725                 Pass                            1
# 4     -79.631265                 Pass                            3
# 5     -79.631265                 Pass                            3
# 6     -79.631265                 Pass                            3
# 10    -79.625845                 Pass                            2
# 11    -79.625845                 Pass                            2
# 14    -79.625310                 Pass                            2
# 17    -79.624158                 Pass                            3
# 18    -79.624158                 Pass                            3
# 19    -79.624158                 Pass                            3
# 20    -79.624158                 Pass                            3
# 21    -79.624158                 Pass                            3
# 25    -79.623935                 Pass                            1
# 26    -79.623935                 Pass                            2
# 27    -79.623935                 Pass                            2
# 31    -79.622937                 Pass                            2
# 32    -79.622937                 Pass                            2
# 33    -79.622419                 Pass                            2
# 34    -79.622419                 Pass                            2
# 35    -79.622419                 Pass                            2
# 38    -79.621963                 Pass                            2
# 39    -79.621963                 Pass                            2
# 43    -79.621343                 Pass                            3
# 44    -79.621343                 Pass                            3
# 45    -79.621343                 Pass                            3
# 49    -79.620046                 Pass                            2
# 52    -79.619844     Conditional Pass                            2
# 53    -79.619844     Conditional Pass                            2
# 54    -79.619844     Conditional Pass                            2
# 55    -79.619844                 Pass                            2
# ...          ...                  ...                          ...
# 90457 -79.141810                 Pass                            1
# 90462 -79.139859                 Pass                            2
# 90464 -79.139779     Conditional Pass                            1
# 90465 -79.139779     Conditional Pass                            1
# 90466 -79.139779                 Pass                            1
# 90467 -79.139779                 Pass                            1
# 90473 -79.139686                 Pass                            3
# 90474 -79.139686                 Pass                            3
# 90481 -79.139527                 Pass                            1
# 90484 -79.139455                 Pass                            1
# 90485 -79.139250                 Pass                            1
# 90486 -79.138826     Conditional Pass                            2
# 90487 -79.138826     Conditional Pass                            2
# 90488 -79.138826                 Pass                            2
# 90489 -79.138826                 Pass                            2
# 90492 -79.138330     Conditional Pass                            2
# 90493 -79.138330     Conditional Pass                            2
# 90494 -79.138330                 Pass                            2
# 90495 -79.138330                 Pass                            2
# 90496 -79.138325                 Pass                            1
# 90498 -79.138325                 Pass                            2
# 90501 -79.137419                 Pass                            2
# 90502 -79.137419                 Pass                            2
# 90505 -79.137254                 Pass                            1
# 90508 -79.137254                 Pass                            2
# 90510 -79.137254                 Pass                            1
# 90511 -79.137254                 Pass                            1
# 90515 -79.130693                 Pass                            2
# 90516 -79.130693                 Pass                            2
# 90517 -79.130693                 Pass                            2
#
#                                       infraction_details inspection_date  \
# 1                                                    NaN      2017-05-25
# 4                                                    NaN      2017-04-27
# 5               Operator fail to properly maintain rooms      2017-08-31
# 6                                                    NaN      2017-12-22
# 10                                                   NaN      2017-05-31
# 11                                                   NaN      2017-10-23
# 14              Operator fail to properly maintain rooms      2017-06-15
# 17        Operator fail to provide hand washing supplies      2017-03-02
# 18              Operator fail to properly maintain rooms      2017-07-27
# 19        Operator fail to provide hand washing supplies      2017-07-27
# 20              Operator fail to properly maintain rooms      2017-11-10
# 21        Operator fail to provide hand washing supplies      2017-11-10
# 25                                                   NaN      2017-06-08
# 26             Operator fail to provide proper equipment      2017-02-13
# 27              Operator fail to properly maintain rooms      2017-09-07
# 31                                                   NaN      2017-06-28
# 32                                                   NaN      2017-11-10
# 33              Operator fail to properly maintain rooms      2017-02-23
# 34     Operator fail to provide separate handwashing ...      2017-02-23
# 35                                                   NaN      2017-09-12
# 38                                                   NaN      2017-05-10
# 39                                                   NaN      2017-11-21
# 43                                                   NaN      2017-04-28
# 44                                                   NaN      2017-08-28
# 45                                                   NaN      2017-12-22
# 49        Operator fail to provide hand washing supplies      2017-09-07
# 52     Fail to Hold a Valid Food Handler's Certificat...      2017-06-08
# 53     Operator fail to provide separate handwashing ...      2017-06-08
# 54            Operator fail to provide washroom supplies      2017-06-08
# 55                                                   NaN      2017-06-15
# ...                                                  ...             ...
# 90457                                                NaN      2017-05-16
# 90462                                                NaN      2017-11-29
# 90464           Operator fail to properly maintain rooms      2017-05-02
# 90465     Operator fail to provide adequate pest control      2017-05-02
# 90466                                                NaN      2017-05-08
# 90467                                                NaN      2017-09-11
# 90473                                                NaN      2017-03-14
# 90474           Operator fail to properly maintain rooms      2017-09-11
# 90481                                                NaN      2017-01-25
# 90484                                                NaN      2017-03-14
# 90485                                                NaN      2017-05-08
# 90486   Operator fail to properly wash surfaces in rooms      2017-08-02
# 90487     Operator fail to provide adequate pest control      2017-08-02
# 90488                                                NaN      2017-08-25
# 90489                                                NaN      2017-11-01
# 90492           Operator fail to properly maintain rooms      2017-01-10
# 90493     Operator fail to provide adequate pest control      2017-01-10
# 90494                                                NaN      2017-01-13
# 90495                                                NaN      2017-09-13
# 90496                                                NaN      2017-04-11
# 90498                                                NaN      2017-05-17
# 90501                                                NaN      2017-01-25
# 90502                                                NaN      2017-09-12
# 90505                                                NaN      2017-05-17
# 90508                                                NaN      2017-05-17
# 90510                                                NaN      2017-01-10
# 90511                                                NaN      2017-09-27
# 90515                                                NaN      2017-02-01
# 90516                                                NaN      2017-05-16
# 90517                                                NaN      2017-10-17
#
#                   severity                       action court_outcome  \
# 1                      NaN                          NaN           NaN
# 4                      NaN                          NaN           NaN
# 5                M - Minor             Notice to Comply           NaN
# 6                      NaN                          NaN           NaN
# 10                     NaN                          NaN           NaN
# 11                     NaN                          NaN           NaN
# 14               M - Minor             Notice to Comply           NaN
# 17         S - Significant  Corrected During Inspection           NaN
# 18               M - Minor             Notice to Comply           NaN
# 19         S - Significant  Corrected During Inspection           NaN
# 20               M - Minor             Notice to Comply           NaN
# 21         S - Significant  Corrected During Inspection           NaN
# 25                     NaN                          NaN           NaN
# 26               M - Minor             Notice to Comply           NaN
# 27               M - Minor             Notice to Comply           NaN
# 31                     NaN                          NaN           NaN
# 32                     NaN                          NaN           NaN
# 33               M - Minor             Notice to Comply           NaN
# 34         S - Significant  Corrected During Inspection           NaN
# 35                     NaN                          NaN           NaN
# 38                     NaN                          NaN           NaN
# 39                     NaN                          NaN           NaN
# 43                     NaN                          NaN           NaN
# 44                     NaN                          NaN           NaN
# 45                     NaN                          NaN           NaN
# 49         S - Significant  Corrected During Inspection           NaN
# 52     NA - Not Applicable             Notice to Comply           NaN
# 53         S - Significant             Notice to Comply           NaN
# 54         S - Significant  Corrected During Inspection           NaN
# 55                     NaN                          NaN           NaN
# ...                    ...                          ...           ...
# 90457                  NaN                          NaN           NaN
# 90462                  NaN                          NaN           NaN
# 90464            M - Minor             Notice to Comply           NaN
# 90465      S - Significant             Notice to Comply           NaN
# 90466                  NaN                          NaN           NaN
# 90467                  NaN                          NaN           NaN
# 90473                  NaN                          NaN           NaN
# 90474            M - Minor             Notice to Comply           NaN
# 90481                  NaN                          NaN           NaN
# 90484                  NaN                          NaN           NaN
# 90485                  NaN                          NaN           NaN
# 90486            M - Minor             Notice to Comply           NaN
# 90487      S - Significant             Notice to Comply           NaN
# 90488                  NaN                          NaN           NaN
# 90489                  NaN                          NaN           NaN
# 90492            M - Minor             Notice to Comply           NaN
# 90493      S - Significant             Notice to Comply           NaN
# 90494                  NaN                          NaN           NaN
# 90495                  NaN                          NaN           NaN
# 90496                  NaN                          NaN           NaN
# 90498                  NaN                          NaN           NaN
# 90501                  NaN                          NaN           NaN
# 90502                  NaN                          NaN           NaN
# 90505                  NaN                          NaN           NaN
# 90508                  NaN                          NaN           NaN
# 90510                  NaN                          NaN           NaN
# 90511                  NaN                          NaN           NaN
# 90515                  NaN                          NaN           NaN
# 90516                  NaN                          NaN           NaN
# 90517                  NaN                          NaN           NaN
#
#        amount_fined  year  quarter  month  week
# 1               NaN  2017        2      5    21
# 4               NaN  2017        2      4    17
# 5               NaN  2017        3      8    35
# 6               NaN  2017        4     12    51
# 10              NaN  2017        2      5    22
# 11              NaN  2017        4     10    43
# 14              NaN  2017        2      6    24
# 17              NaN  2017        1      3     9
# 18              NaN  2017        3      7    30
# 19              NaN  2017        3      7    30
# 20              NaN  2017        4     11    45
# 21              NaN  2017        4     11    45
# 25              NaN  2017        2      6    23
# 26              NaN  2017        1      2     7
# 27              NaN  2017        3      9    36
# 31              NaN  2017        2      6    26
# 32              NaN  2017        4     11    45
# 33              NaN  2017        1      2     8
# 34              NaN  2017        1      2     8
# 35              NaN  2017        3      9    37
# 38              NaN  2017        2      5    19
# 39              NaN  2017        4     11    47
# 43              NaN  2017        2      4    17
# 44              NaN  2017        3      8    35
# 45              NaN  2017        4     12    51
# 49              NaN  2017        3      9    36
# 52              NaN  2017        2      6    23
# 53              NaN  2017        2      6    23
# 54              NaN  2017        2      6    23
# 55              NaN  2017        2      6    24
# ...             ...   ...      ...    ...   ...
# 90457           NaN  2017        2      5    20
# 90462           NaN  2017        4     11    48
# 90464           NaN  2017        2      5    18
# 90465           NaN  2017        2      5    18
# 90466           NaN  2017        2      5    19
# 90467           NaN  2017        3      9    37
# 90473           NaN  2017        1      3    11
# 90474           NaN  2017        3      9    37
# 90481           NaN  2017        1      1     4
# 90484           NaN  2017        1      3    11
# 90485           NaN  2017        2      5    19
# 90486           NaN  2017        3      8    31
# 90487           NaN  2017        3      8    31
# 90488           NaN  2017        3      8    34
# 90489           NaN  2017        4     11    44
# 90492           NaN  2017        1      1     2
# 90493           NaN  2017        1      1     2
# 90494           NaN  2017        1      1     2
# 90495           NaN  2017        3      9    37
# 90496           NaN  2017        2      4    15
# 90498           NaN  2017        2      5    20
# 90501           NaN  2017        1      1     4
# 90502           NaN  2017        3      9    37
# 90505           NaN  2017        2      5    20
# 90508           NaN  2017        2      5    20
# 90510           NaN  2017        1      1     2
# 90511           NaN  2017        3      9    39
# 90515           NaN  2017        1      2     5
# 90516           NaN  2017        2      5    20
# 90517           NaN  2017        4     10    42
#
# [44132 rows x 20 columns]

# %%
inspection_17= data_17.groupby(['year','month'])['inspection_id'].nunique().reset_index()
#inspection_17=inspection_17.set_index(['year','week'])
inspection_17
# Out:
#     year  month  inspection_id
# 0   2017      1           1834
# 1   2017      2           2125
# 2   2017      3           2469
# 3   2017      4           2064
# 4   2017      5           2136
# 5   2017      6           2533
# 6   2017      7           1978
# 7   2017      8           2387
# 8   2017      9           2189
# 9   2017     10           2604
# 10  2017     11           2637
# 11  2017     12           2409

# %%
ax1= inspection_17.plot(x='month',y='inspection_id',figsize=(20,8))
#inspection_17.plot(x='week',y='inspection_id',figsize=(20,8))
#plt.xticks(np.arange(min(x), max(x)+1, 1.0))
ax1.set_xticks(inspection_17.month[::1])
ax1.set_xticklabels(inspection_17.month[::1], rotation=45)
ax1.set_title("Every 2nd ticks on x axis")
# Out:
# [<matplotlib.axis.XTick at 0x1a2191c400>,
#  <matplotlib.axis.XTick at 0x1a218aacf8>,
#  <matplotlib.axis.XTick at 0x1a218ec2b0>,
#  <matplotlib.axis.XTick at 0x1a21687ac8>,
#  <matplotlib.axis.XTick at 0x1a218f3400>,
#  <matplotlib.axis.XTick at 0x1a218f34a8>,
#  <matplotlib.axis.XTick at 0x1a218f3940>,
#  <matplotlib.axis.XTick at 0x1a21687358>,
#  <matplotlib.axis.XTick at 0x1a218aaa58>,
#  <matplotlib.axis.XTick at 0x1a21671ba8>,
#  <matplotlib.axis.XTick at 0x1a214f49b0>,
#  <matplotlib.axis.XTick at 0x1a214f4160>]
# [Text(0,0,'1'),
#  Text(0,0,'2'),
#  Text(0,0,'3'),
#  Text(0,0,'4'),
#  Text(0,0,'5'),
#  Text(0,0,'6'),
#  Text(0,0,'7'),
#  Text(0,0,'8'),
#  Text(0,0,'9'),
#  Text(0,0,'10'),
#  Text(0,0,'11'),
#  Text(0,0,'12')]
# Text(0.5,1,'Every 2nd ticks on x axis')

# %%
freq_table=data.groupby(['minimum_inspections_peryear','establishment_status']).size()

# %%
f_table=freq_table.to_frame()
f_table.columns = ['number_of_result']
#f_table.reset_index(level=['minimum_inspections_peryear'])
f_table=f_table.reset_index()

# %%
aa=pd.get_dummies(f_table)
aa.drop(['minimum_inspections_peryear'], axis=1)
cols = list(aa.columns.values)
#cols
aa = aa[[
 'establishment_status_Closed',
 'establishment_status_Conditional Pass',
 'establishment_status_Pass','minimum_inspections_peryear','number_of_result']]
# Out:
#    number_of_result  establishment_status_Closed  \
# 0                 4                            1
# 1               457                            0
# 2              7135                            0
# 3                62                            1
# 4              5825                            0
# 5             38408                            0
# 6               286                            1
# 7             10955                            0
# 8             27388                            0
#
#    establishment_status_Conditional Pass  establishment_status_Pass
# 0                                      0                          0
# 1                                      1                          0
# 2                                      0                          1
# 3                                      0                          0
# 4                                      1                          0
# 5                                      0                          1
# 6                                      0                          0
# 7                                      1                          0
# 8                                      0                          1

# %%
aa
# Out:
#    establishment_status_Closed  establishment_status_Conditional Pass  \
# 0                            1                                      0
# 1                            0                                      1
# 2                            0                                      0
# 3                            1                                      0
# 4                            0                                      1
# 5                            0                                      0
# 6                            1                                      0
# 7                            0                                      1
# 8                            0                                      0
#
#    establishment_status_Pass  minimum_inspections_peryear  number_of_result
# 0                          0                            1                 4
# 1                          0                            1               457
# 2                          1                            1              7135
# 3                          0                            2                62
# 4                          0                            2              5825
# 5                          1                            2             38408
# 6                          0                            3               286
# 7                          0                            3             10955
# 8                          1                            3             27388
